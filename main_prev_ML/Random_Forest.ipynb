# %%
import pandas as pd
main_prev = pd.read_csv('/Users/hazel/Documents/credit_project_data/Jen-Chao Huang/main_prev.csv',index_col=0)
main_prev.info(verbose=True)
#HOUR_APPR_PROCESS_START_x(main),HOUR_APPR_PROCESS_START(prev)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338096 entries, 0 to 338095
# Data columns (total 119 columns):
#  #    Column                                    Dtype
# ---   ------                                    -----
#  0    SK_ID_CURR                                int64
#  1    PREV_ANNUITY_median                       float64
#  2    PREV_CREDIT_sum                           float64
#  3    PREV_DOWN_PAYMENT_median                  float64
#  4    PREV_CRE/APP_max                          float64
#  5    RATE_DOWN_PAYMENT_median                  float64
#  6    RATE_INTEREST_PRIMARY_median              float64
#  7    RATE_INTEREST_PRIMARY_max                 float64
#  8    DAYS_DECISION_median                      float64
#  9    CNT_PAYMENT_median                        float64
#  10   DAYS_PERIOD_median                        float64
#  11   PAYMENT_CASH_BANK                         float64
#  12   PAYMENT_ACCOUNT_EMPLOYER                  float64
# ...

# %%
feature = main_prev[['PREV_ANNUITY_median', 'PREV_CREDIT_sum', 'DAYS_DECISION_median',
       'DAYS_PERIOD_median', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
       'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'DAYS_LAST_PHONE_CHANGE']]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE


X = feature
y = main_prev[['late_count_inLoan / Loan_count']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# SMOTE方法
#X_res, y_res = SMOTE(random_state=42).fit_resample(X_train,y_train)


scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

model2 = RandomForestClassifier(max_depth=4, n_estimators=100)
model2.fit(X_train, y_train)

X_test = scaler.transform(X_test)
y_pred = model2.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
num_correct_samples = accuracy_score(y_test, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test, y_pred)
f1_score = f1_score(y_test, y_pred, average=None)
cross_val_score = cross_val_score(model2,X,y,cv=10,scoring='accuracy')

print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('con_matrix: {}'.format(con_matrix))
print('f1_score: {}'.format(f1_score))
print('cross_val_score: {}'.format(cross_val_score))
print('cross_val_score_mean: {}'.format(cross_val_score.mean()))
print('訓練集：{}'.format(model.score(X_train, y_train)))
print('測試集：{}'.format(model.score(X_test,y_test)))
# Out:
# /var/folders/dp/hcv7h_qn59b6dcz6l8v_w1z80000gn/T/ipykernel_35765/3592308605.py:23: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model2.fit(X_train, y_train)
# /Users/hazel/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/hazel/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
import joblib
joblib.dump(model2,'main_prev_randomforest_ml2')
# Out:
# ['main_prev_randomforest_ml2']

# %%
feature = main_prev[['PREV_ANNUITY_median', 'PREV_CREDIT_sum', 'PREV_DOWN_PAYMENT_median',
       'RATE_DOWN_PAYMENT_median', 'DAYS_DECISION_median',
       'CNT_PAYMENT_median', 'DAYS_PERIOD_median', 'PAYMENT_CASH_BANK',
       'YIELD_high', 'YIELD_middle', 'HOUR_APPR_PROCESS_START',
       'WEEKDAY_APPR_PROCESS_START', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
       'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
       'HOUR_APPR_PROCESS_START_x', 'DAYS_LAST_PHONE_CHANGE',
       'AMT_REQ_CREDIT_BUREAU_YEAR']]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE


X = feature
y = main_prev[['late_count_inLoan / Loan_count']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# SMOTE方法
# X_res, y_res = SMOTE(random_state=42).fit_resample(X_train,y_train)


scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

model = RandomForestClassifier(max_depth=4, n_estimators=100)
model.fit(X_train, y_train)

X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
num_correct_samples = accuracy_score(y_test, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test, y_pred)
f1_score = f1_score(y_test, y_pred, average=None)
cross_val_score = cross_val_score(model,X,y,cv=10,scoring='accuracy')

print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('con_matrix: {}'.format(con_matrix))
print('f1_score: {}'.format(f1_score))
print('cross_val_score: {}'.format(cross_val_score))
print('cross_val_score_mean: {}'.format(cross_val_score.mean()))
print('訓練集：{}'.format(model.score(X_train, y_train)))
print('測試集：{}'.format(model.score(X_test,y_test)))
# Out:
# /var/folders/dp/hcv7h_qn59b6dcz6l8v_w1z80000gn/T/ipykernel_35765/3878966523.py:23: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# /Users/hazel/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/hazel/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
import joblib
joblib.dump(model,'main_prev_randomforest')
# Out:
# ['main_prev_randomforest']
